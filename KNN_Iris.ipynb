# %%
# K Nearest Neighbors (KNN) Algorithm Implementation

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
# K Nearest Neighbors (KNN) is a simple, instance-based learning algorithm 
# used for classification and regression tasks. It works by finding the 'k' closest 
# data points (neighbors) to a given input and making predictions based on the 
# majority class (for classification) or average value (for regression) 
# of those neighbors.

# Lazy Learning: KNN is a lazy learning algorithm, meaning it does not build a model 
# during the training phase. Instead, it stores the training data and makes predictions
# only when a query is made.

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
# Preprocess the data
# check the data
import pandas as pd
X_df = pd.DataFrame(X, columns=iris.feature_names)
X_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# apply KNN algorithm
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10, p = 2)  # p=2 for Euclidean distance
knn.fit(X_train, y_train)

# see the clusters of the data
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title('Iris Dataset Clusters')
plt.show()

# %%
# Check accuracy of the model
accuracy = knn.score(X_test, y_test)   
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.97

# %%
# other model evaluation metrics
from sklearn.metrics import classification_report, confusion_matrix
y_pred = knn.predict(X_test)
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 8  0  0]
#  [ 0 10  1]
#  [ 0  0 11]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      0.91      0.95        11
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred_train = knn.predict(X_train)
print("Confusion Matrix:")
print(confusion_matrix(y_train, y_pred_train))
print("\nClassification Report:")
print(classification_report(y_train, y_pred_train))
# Out:
# Confusion Matrix:
# [[42  0  0]
#  [ 0 38  1]
#  [ 0  1 38]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
#            1       0.97      0.97      0.97        39
#            2       0.97      0.97      0.97        39
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.98      0.98       120
# weighted avg       0.98      0.98      0.98       120
